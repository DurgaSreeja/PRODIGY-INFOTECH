# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("train.csv")
data.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
data["MSZoning"]=data["MSZoning"].astype('category')
data["MSZoning"]=data["MSZoning"].cat.codes
data["MSZoning"]
# Out:
# 0       3
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 1455    3
# 1456    3
# 1457    3
# 1458    3
# 1459    3
# Name: MSZoning, Length: 1460, dtype: int8

# %%
data["LotFrontage"]=data["LotFrontage"].replace(["NA"],0).replace(np.nan,0)
data["LotFrontage"]
# Out:
# 0       65.0
# 1       80.0
# 2       68.0
# 3       60.0
# 4       84.0
#         ...
# 1455    62.0
# 1456    85.0
# 1457    66.0
# 1458    68.0
# 1459    75.0
# Name: LotFrontage, Length: 1460, dtype: float64

# %%
data.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 81, dtype: int64

# %%
data["Street"]=data["Street"].astype('category')
data["Street"]=data["Street"].cat.codes
data["Alley"]=data["Alley"].astype('category')
data["Alley"]=data["Alley"].cat.codes
data["LotShape"]=data["LotShape"].astype('category')
data["LotShape"]=data["LotShape"].cat.codes
data["LandContour"]=data["LandContour"].astype('category')
data["LandContour"]=data["LandContour"].cat.codes
data["Utilities"]=data["Utilities"].astype('category')
data["Utilities"]=data["Utilities"].cat.codes
data["LotConfig"]=data["LotConfig"].astype('category')
data["LotConfig"]=data["LotConfig"].cat.codes
data["LandSlope"]=data["LandSlope"].astype('category')
data["LandSlope"]=data["LandSlope"].cat.codes
data["Neighborhood"]=data["Neighborhood"].astype('category')
data["Neighborhood"]=data["Neighborhood"].cat.codes
data["Condition1"]=data["Condition1"].astype('category')
data["Condition1"]=data["Condition1"].cat.codes
data["Condition2"]=data["Condition2"].astype('category')
data["Condition2"]=data["Condition2"].cat.codes
data["BldgType"]=data["BldgType"].astype('category')
data["BldgType"]=data["BldgType"].cat.codes
data["HouseStyle"]=data["HouseStyle"].astype('category')
data["HouseStyle"]=data["HouseStyle"].cat.codes
data["OverallCond"]=data["OverallCond"].astype('category')
data["OverallCond"]=data["OverallCond"].cat.codes
data["OverallQual"]=data["OverallQual"].astype('category')
data["OverallQual"]=data["OverallQual"].cat.codes
data["YearBuilt"]=data["YearBuilt"].astype('category')
data["YearBuilt"]=data["YearBuilt"].cat.codes
data["YearRemodAdd"]=data["YearRemodAdd"].astype('category')
data["YearRemodAdd"]=data["YearRemodAdd"].cat.codes
data["RoofStyle"]=data["RoofStyle"].astype('category')
data["RoofStyle"]=data["RoofStyle"].cat.codes
data["RoofMatl"]=data["RoofMatl"].astype('category')
data["RoofMatl"]=data["RoofMatl"].cat.codes
data["Exterior1st"]=data["Exterior1st"].astype('category')
data["Exterior1st"]=data["Exterior1st"].cat.codes
data["Exterior2nd"]=data["Exterior2nd"].astype('category')
data["Exterior2nd"]=data["Exterior2nd"].cat.codes

# %%
data["MasVnrType"]=data["MasVnrType"].replace("None","NA")
data["MasVnrType"]=data["MasVnrType"].astype('category')
data["MasVnrType"]=data["MasVnrType"].cat.codes
data["MasVnrArea"]=data["MasVnrArea"].replace("NA",-1).replace(np.nan,-1)
data["ExterQual"]=data["ExterQual"].astype('category')
data["ExterQual"]=data["ExterQual"].cat.codes
data["ExterCond"]=data["ExterCond"].astype('category')
data["ExterCond"]=data["ExterCond"].cat.codes
data["Foundation"]=data["Foundation"].astype('category')
data["Foundation"]=data["Foundation"].cat.codes
data["BsmtQual"]=data["BsmtQual"].astype('category')
data["BsmtQual"]=data["BsmtQual"].cat.codes
data["BsmtCond"]=data["BsmtCond"].astype('category')
data["BsmtCond"]=data["BsmtCond"].cat.codes
data["BsmtExposure"]=data["BsmtExposure"].astype('category')
data["BsmtExposure"]=data["BsmtExposure"].cat.codes
data["BsmtFinType1"]=data["BsmtFinType1"].astype('category')
data["BsmtFinType1"]=data["BsmtFinType1"].cat.codes
data["BsmtFinType2"]=data["BsmtFinType2"].astype('category')
data["BsmtFinType2"]=data["BsmtFinType2"].cat.codes
data["Heating"]=data["Heating"].astype('category')
data["Heating"]=data["Heating"].cat.codes
data["HeatingQC"]=data["HeatingQC"].astype('category')
data["HeatingQC"]=data["HeatingQC"].cat.codes
data["CentralAir"]=data["CentralAir"].astype('category')
data["CentralAir"]=data["CentralAir"].cat.codes
data["Electrical"]=data["Electrical"].astype('category')
data["Electrical"]=data["Electrical"].cat.codes
data["KitchenQual"]=data["KitchenQual"].astype('category')
data["KitchenQual"]=data["KitchenQual"].cat.codes
data["Functional"]=data["Functional"].astype('category')
data["Functional"]=data["Functional"].cat.codes
data["FireplaceQu"]=data["FireplaceQu"].astype('category')
data["FireplaceQu"]=data["FireplaceQu"].cat.codes
data["GarageType"]=data["GarageType"].astype('category')
data["GarageType"]=data["GarageType"].cat.codes
data["GarageFinish"]=data["GarageFinish"].astype('category')
data["GarageFinish"]=data["GarageFinish"].cat.codes
data["GarageQual"]=data["GarageQual"].astype('category')
data["GarageQual"]=data["GarageQual"].cat.codes
data["GarageCond"]=data["GarageCond"].astype('category')
data["GarageCond"]=data["GarageCond"].cat.codes

# %%
data["PavedDrive"]=data["PavedDrive"].astype('category')
data["PavedDrive"]=data["PavedDrive"].cat.codes
data["PoolQC"]=data["PoolQC"].astype('category')
data["PoolQC"]=data["PoolQC"].cat.codes
data["Fence"]=data["Fence"].astype('category')
data["Fence"]=data["Fence"].cat.codes
data["MiscFeature"]=data["MiscFeature"].astype('category')
data["MiscFeature"]=data["MiscFeature"].cat.codes
data["SaleType"]=data["SaleType"].astype('category')
data["SaleType"]=data["SaleType"].cat.codes
data["SaleCondition"]=data["SaleCondition"].astype('category')
data["SaleCondition"]=data["SaleCondition"].cat.codes

# %%
data.fillna(data.mean())
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0        1          60         3         65.0     8450       1      0
# 1        2          20         3         80.0     9600       1      0
# 2        3          60         3         68.0    11250       1      0
# 3        4          70         3         60.0     9550       1      0
# 4        5          60         3         84.0    14260       1      0
# ...    ...         ...       ...          ...      ...     ...    ...
# 1455  1456          60         3         62.0     7917       1      0
# 1456  1457          20         3         85.0    13175       1      0
# 1457  1458          70         3         66.0     9042       1      0
# 1458  1459          20         3         68.0     9717       1      0
# 1459  1460          20         3         75.0     9937       1      0
#
#       LotShape  LandContour  Utilities  ...  PoolArea  PoolQC  Fence  \
# ...

# %%
for col in data:
    print(data[col].unique())
# Out:
# [   1    2    3 ... 1458 1459 1460]
# [ 60  20  70  50 190  45  90 120  30  85  80 160  75 180  40]
# [3 4 0 1 2]
# [ 65.  80.  68.  60.  84.  85.  75.   0.  51.  50.  70.  91.  72.  66.
#  101.  57.  44. 110.  98.  47. 108. 112.  74. 115.  61.  48.  33.  52.
#  100.  24.  89.  63.  76.  81.  95.  69.  21.  32.  78. 121. 122.  40.
#  105.  73.  77.  64.  94.  34.  90.  55.  88.  82.  71. 120. 107.  92.
#  134.  62.  86. 141.  97.  54.  41.  79. 174.  99.  67.  83.  43. 103.
#   93.  30. 129. 140.  35.  37. 118.  87. 116. 150. 111.  49.  96.  59.
#   36.  56. 102.  58.  38. 109. 130.  53. 137.  45. 106. 104.  42.  39.
#  144. 114. 128. 149. 313. 168. 182. 138. 160. 152. 124. 153.  46.]
# [ 8450  9600 11250 ... 17217 13175  9717]
# [1 0]
# [0 1 2]
# [3 0 1 2]
# [3 0 2 1]
# [0 1]
# [4 2 0 1 3]
# [0 1 2]
# [ 5 24  6 15 11 21 14 17  3 19 16 12 20  9 10  7 23  8 22  4 13  0  2 18
#   1]
# [2 1 4 0 5 8 6 3 7]
# [2 0 7 1 4 3 6 5]
# [0 1 2 4 3]
# [5 2 0 1 6 7 4 3]
# [6 5 7 4 8 3 9 2 0 1]
# ...

# %%
data.columns[data.isna().any()].tolist()
# Out:
# ['GarageYrBlt']

# %%
data["GarageYrBlt"]=data["GarageYrBlt"].replace(np.nan,-1)
data["GarageYrBlt"].unique()
# Out:
# array([ 2.003e+03,  1.976e+03,  2.001e+03,  1.998e+03,  2.000e+03,
#         1.993e+03,  2.004e+03,  1.973e+03,  1.931e+03,  1.939e+03,
#         1.965e+03,  2.005e+03,  1.962e+03,  2.006e+03,  1.960e+03,
#         1.991e+03,  1.970e+03,  1.967e+03,  1.958e+03,  1.930e+03,
#         2.002e+03,  1.968e+03,  2.007e+03,  2.008e+03,  1.957e+03,
#         1.920e+03,  1.966e+03,  1.959e+03,  1.995e+03,  1.954e+03,
#         1.953e+03, -1.000e+00,  1.983e+03,  1.977e+03,  1.997e+03,
#         1.985e+03,  1.963e+03,  1.981e+03,  1.964e+03,  1.999e+03,
#         1.935e+03,  1.990e+03,  1.945e+03,  1.987e+03,  1.989e+03,
#         1.915e+03,  1.956e+03,  1.948e+03,  1.974e+03,  2.009e+03,
#         1.950e+03,  1.961e+03,  1.921e+03,  1.900e+03,  1.979e+03,
#         1.951e+03,  1.969e+03,  1.936e+03,  1.975e+03,  1.971e+03,
#         1.923e+03,  1.984e+03,  1.926e+03,  1.955e+03,  1.986e+03,
#         1.988e+03,  1.916e+03,  1.932e+03,  1.972e+03,  1.918e+03,
# ...

# %%
X=data.iloc[:,:-1]
Y=data.iloc[:,-1]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)
X
# Out:
# array([[-1.73086488,  0.07337496, -0.04553194, ...,  0.13877749,
#          0.31386709,  0.2085023 ],
#        [-1.7284922 , -0.87256276, -0.04553194, ..., -0.61443862,
#          0.31386709,  0.2085023 ],
#        [-1.72611953,  0.07337496, -0.04553194, ...,  0.13877749,
#          0.31386709,  0.2085023 ],
#        ...,
#        [ 1.72611953,  0.30985939, -0.04553194, ...,  1.64520971,
#          0.31386709,  0.2085023 ],
#        [ 1.7284922 , -0.87256276, -0.04553194, ...,  1.64520971,
#          0.31386709,  0.2085023 ],
#        [ 1.73086488, -0.87256276, -0.04553194, ...,  0.13877749,
#          0.31386709,  0.2085023 ]])

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X, Y)
# Out:
# LinearRegression()

# %%
test=pd.read_csv("test.csv")

# %%
test["MSZoning"]=test["MSZoning"].astype('category')
test["MSZoning"]=test["MSZoning"].cat.codes
test["LotFrontage"]=test["LotFrontage"].replace(["NA"],0).replace(np.nan,0)
test["LotFrontage"]
test["Street"]=test["Street"].astype('category')
test["Street"]=test["Street"].cat.codes
test["Alley"]=test["Alley"].astype('category')
test["Alley"]=test["Alley"].cat.codes
test["LotShape"]=test["LotShape"].astype('category')
test["LotShape"]=test["LotShape"].cat.codes
test["LandContour"]=test["LandContour"].astype('category')
test["LandContour"]=test["LandContour"].cat.codes
test["Utilities"]=test["Utilities"].astype('category')
test["Utilities"]=test["Utilities"].cat.codes
test["LotConfig"]=test["LotConfig"].astype('category')
test["LotConfig"]=test["LotConfig"].cat.codes
test["LandSlope"]=test["LandSlope"].astype('category')
test["LandSlope"]=test["LandSlope"].cat.codes
test["Neighborhood"]=test["Neighborhood"].astype('category')
test["Neighborhood"]=test["Neighborhood"].cat.codes
test["Condition1"]=test["Condition1"].astype('category')
test["Condition1"]=test["Condition1"].cat.codes
test["Condition2"]=test["Condition2"].astype('category')
test["Condition2"]=test["Condition2"].cat.codes
test["BldgType"]=test["BldgType"].astype('category')
test["BldgType"]=test["BldgType"].cat.codes
test["HouseStyle"]=test["HouseStyle"].astype('category')
test["HouseStyle"]=test["HouseStyle"].cat.codes
test["OverallCond"]=test["OverallCond"].astype('category')
test["OverallCond"]=test["OverallCond"].cat.codes
test["OverallQual"]=test["OverallQual"].astype('category')
test["OverallQual"]=test["OverallQual"].cat.codes
test["YearBuilt"]=test["YearBuilt"].astype('category')
test["YearBuilt"]=test["YearBuilt"].cat.codes
test["YearRemodAdd"]=test["YearRemodAdd"].astype('category')
test["YearRemodAdd"]=test["YearRemodAdd"].cat.codes
test["RoofStyle"]=test["RoofStyle"].astype('category')
test["RoofStyle"]=test["RoofStyle"].cat.codes
test["RoofMatl"]=test["RoofMatl"].astype('category')
test["RoofMatl"]=test["RoofMatl"].cat.codes
test["Exterior1st"]=test["Exterior1st"].astype('category')
test["Exterior1st"]=test["Exterior1st"].cat.codes
test["Exterior2nd"]=test["Exterior2nd"].astype('category')
test["Exterior2nd"]=test["Exterior2nd"].cat.codes

# %%
test["MasVnrType"]=test["MasVnrType"].replace("None","NA")
test["MasVnrType"]=test["MasVnrType"].astype('category')
test["MasVnrType"]=test["MasVnrType"].cat.codes
test["MasVnrArea"]=test["MasVnrArea"].replace("NA",-1).replace(np.nan,-1)
test["ExterQual"]=test["ExterQual"].astype('category')
test["ExterQual"]=test["ExterQual"].cat.codes
test["ExterCond"]=test["ExterCond"].astype('category')
test["ExterCond"]=test["ExterCond"].cat.codes
test["Foundation"]=test["Foundation"].astype('category')
test["Foundation"]=test["Foundation"].cat.codes
test["BsmtQual"]=test["BsmtQual"].astype('category')
test["BsmtQual"]=test["BsmtQual"].cat.codes
test["BsmtCond"]=test["BsmtCond"].astype('category')
test["BsmtCond"]=test["BsmtCond"].cat.codes
test["BsmtExposure"]=test["BsmtExposure"].astype('category')
test["BsmtExposure"]=test["BsmtExposure"].cat.codes
test["BsmtFinType1"]=test["BsmtFinType1"].astype('category')
test["BsmtFinType1"]=test["BsmtFinType1"].cat.codes
test["BsmtFinType2"]=test["BsmtFinType2"].astype('category')
test["BsmtFinType2"]=test["BsmtFinType2"].cat.codes
test["Heating"]=test["Heating"].astype('category')
test["Heating"]=test["Heating"].cat.codes
test["HeatingQC"]=test["HeatingQC"].astype('category')
test["HeatingQC"]=test["HeatingQC"].cat.codes
test["CentralAir"]=test["CentralAir"].astype('category')
test["CentralAir"]=test["CentralAir"].cat.codes
test["Electrical"]=test["Electrical"].astype('category')
test["Electrical"]=test["Electrical"].cat.codes
test["KitchenQual"]=test["KitchenQual"].astype('category')
test["KitchenQual"]=test["KitchenQual"].cat.codes
test["Functional"]=test["Functional"].astype('category')
test["Functional"]=test["Functional"].cat.codes
test["FireplaceQu"]=test["FireplaceQu"].astype('category')
test["FireplaceQu"]=test["FireplaceQu"].cat.codes
test["GarageType"]=test["GarageType"].astype('category')
test["GarageType"]=test["GarageType"].cat.codes
test["GarageFinish"]=test["GarageFinish"].astype('category')
test["GarageFinish"]=test["GarageFinish"].cat.codes
test["GarageQual"]=test["GarageQual"].astype('category')
test["GarageQual"]=test["GarageQual"].cat.codes
test["GarageCond"]=test["GarageCond"].astype('category')
test["GarageCond"]=test["GarageCond"].cat.codes

# %%
test["PavedDrive"]=test["PavedDrive"].astype('category')
test["PavedDrive"]=test["PavedDrive"].cat.codes
test["PoolQC"]=test["PoolQC"].astype('category')
test["PoolQC"]=test["PoolQC"].cat.codes
test["Fence"]=test["Fence"].astype('category')
test["Fence"]=test["Fence"].cat.codes
test["MiscFeature"]=test["MiscFeature"].astype('category')
test["MiscFeature"]=test["MiscFeature"].cat.codes
test["SaleType"]=test["SaleType"].astype('category')
test["SaleType"]=test["SaleType"].cat.codes
test["SaleCondition"]=test["SaleCondition"].astype('category')
test["SaleCondition"]=test["SaleCondition"].cat.codes

# %%
test.columns[test.isna().any()].tolist()
# Out:
# ['BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea']

# %%
test["BsmtFinSF1"]=test["BsmtFinSF1"].replace(np.nan,-1)
test["BsmtFinSF2"]=test["BsmtFinSF2"].replace(np.nan,-1)
test["BsmtUnfSF"]=test["BsmtUnfSF"].replace(np.nan,-1)
test["TotalBsmtSF"]=test["TotalBsmtSF"].replace(np.nan,-1)
test["BsmtFullBath"]=test["BsmtFullBath"].replace(np.nan,-1)
test["BsmtHalfBath"]=test["BsmtHalfBath"].replace(np.nan,-1)
test["GarageArea"]=test["GarageArea"].replace(np.nan,-1)
test["GarageCars"]=test["GarageCars"].replace(np.nan,-1)
test["GarageYrBlt"]=test["GarageYrBlt"].replace(np.nan,-1)

# %%
test.columns[test.isna().any()].tolist()
# Out:
# []

# %%
test_y=pd.read_csv("sample_submission.csv")
y_test=test_y.iloc[:,-1]
y_test
# Out:
# 0       169277.052498
# 1       187758.393989
# 2       183583.683570
# 3       179317.477511
# 4       150730.079977
#             ...
# 1454    167081.220949
# 1455    164788.778231
# 1456    219222.423400
# 1457    184924.279659
# 1458    187741.866657
# Name: SalePrice, Length: 1459, dtype: float64

# %%
x=test.iloc[:,:]
x = sc.fit_transform(x)
x
# Out:
# array([[-1.73086406, -0.87471081, -1.4199259 , ...,  1.71390537,
#          0.32555481,  0.20138321],
#        [-1.72848977, -0.87471081, -0.02203664, ...,  1.71390537,
#          0.32555481,  0.20138321],
#        [-1.72611547,  0.06135085, -0.02203664, ...,  1.71390537,
#          0.32555481,  0.20138321],
#        ...,
#        [ 1.72611547, -0.87471081, -0.02203664, ..., -1.35995811,
#          0.32555481, -3.58981811],
#        [ 1.72848977,  0.64638939, -0.02203664, ..., -1.35995811,
#          0.32555481,  0.20138321],
#        [ 1.73086406,  0.06135085, -0.02203664, ..., -1.35995811,
#          0.32555481,  0.20138321]])

# %%
y_pred = regressor.predict(x)
y_pred
# Out:
# array([-3.87568669e+15,  1.42773849e+14, -8.88984555e+14, ...,
#        -8.30935077e+14, -3.81698741e+15,  1.21026705e+15])

# %%
y_pred2 = regressor.predict(X)
y_pred2
# Out:
# array([216950.71906938, 200462.7785354 , 213731.20753859, ...,
#        248768.74647691, 148707.11159809, 162192.87330811])

# %%
test.iloc[:,0]
# Out:
# 0       1461
# 1       1462
# 2       1463
# 3       1464
# 4       1465
#         ...
# 1454    2915
# 1455    2916
# 1456    2917
# 1457    2918
# 1458    2919
# Name: Id, Length: 1459, dtype: int64

# %%
plt.plot(test.iloc[:,0],y_test,color="r")
plt.scatter(test.iloc[:,0],y_pred,color="g")
plt.show()

# %%
plt.style.use('default')
plt.style.use('ggplot')

fig, ax = plt.subplots(figsize=(7, 3.5))

ax.plot(test.iloc[:,0], y_pred, color='g', label='Regression model')
ax.scatter(test.iloc[:,0], y_test, edgecolor='r', facecolor='grey', alpha=0.7, label='Sample data')
ax.legend(facecolor='white', fontsize=11)
ax.text(0.55, 0.15, '$y = %.2f x_1 - %.2f $' % (regressor.coef_[0], abs(regressor.intercept_)), fontsize=17, transform=ax.transAxes)

fig.tight_layout()

# %%
import seaborn as sns

ax1 = sns.distplot(Y, hist=False, color="r", label="Actual Value")
sns.distplot(y_pred2, hist=False, color="b", label="Fitted Values" , ax=ax1)
# Out:
# C:\Users\Durga Sreeja\AppData\Local\Temp\ipykernel_11964\2549546908.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1 = sns.distplot(Y, hist=False, color="r", label="Actual Value")
# C:\Users\Durga Sreeja\AppData\Local\Temp\ipykernel_11964\2549546908.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
from sklearn.metrics import r2_score
score=r2_score(Y,y_pred2)
score
# Out:
# 0.8679218757724918
